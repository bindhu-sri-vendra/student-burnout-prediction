# %% [raw]
# Problem Statement
#
# ML model that predicts the burnout level of a student based on various factors like academic performance, Physical Activity level, phycological metrics and lifestyle routines.
# The goal is to identify the students that require academic or mental health support.
#
# Output: A predictive system that classifies student burnout risk and provides interpretable insights into contributing factors.
#
# Note >> Dataset is synthetic due to limited availability of real-world burnout datasets. Extensive validation and domain-based cleaning were applied to improve realism.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
import joblib

from sklearn.model_selection import train_test_split
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.metrics import classification_report, confusion_matrix

# %%
df = pd.read_csv('student_mental_health_burnout.csv',low_memory=True)

# %%
df.head()
# Out:
#    age gender  academic_year  study_hours_per_day  exam_pressure  \
# 0   23   Male              2             5.596071       6.487218
# 1   20   Male              3             5.597171       5.631481
# 2   29   Male              2             2.580491       6.015297
# 3   27   Male              4             4.607208       6.684005
# 4   24   Male              4             2.186569       4.010945
#
#    academic_performance  stress_level  anxiety_score  depression_score  \
# 0             68.411114      4.116950       2.275713          1.986730
# 1             67.682159      0.349489       0.000000          0.000000
# 2             58.372363      3.476177       2.425201          0.851996
# 3             68.925653      6.778843       4.512425          4.285645
# 4             69.141915      1.854595       1.102558          0.000000
#
#    sleep_hours  physical_activity  social_support  screen_time  \
# 0     6.880545           2.728861        6.470080     4.993801
# ...

# %%
df.shape
# Out:
# (1000000, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 20 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   age                   1000000 non-null  int64
#  1   gender                1000000 non-null  object
#  2   academic_year         1000000 non-null  int64
#  3   study_hours_per_day   1000000 non-null  float64
#  4   exam_pressure         1000000 non-null  float64
#  5   academic_performance  1000000 non-null  float64
#  6   stress_level          1000000 non-null  float64
#  7   anxiety_score         1000000 non-null  float64
#  8   depression_score      1000000 non-null  float64
#  9   sleep_hours           1000000 non-null  float64
#  10  physical_activity     1000000 non-null  float64
#  11  social_support        1000000 non-null  float64
#  12  screen_time           1000000 non-null  float64
#  13  internet_usage        1000000 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# age                     0
# gender                  0
# academic_year           0
# study_hours_per_day     0
# exam_pressure           0
# academic_performance    0
# stress_level            0
# anxiety_score           0
# depression_score        0
# sleep_hours             0
# physical_activity       0
# social_support          0
# screen_time             0
# internet_usage          0
# financial_stress        0
# family_expectation      0
# burnout_score           0
# mental_health_index     0
# risk_level              0
# dropout_risk            0
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
# Creating a smaller random sample of 10,000 rows for quick testing and visualization
sample_df = df.sample(10000, random_state=42)

# Creating a training subset of 200,000 rows from the dataset for model training
train_df = df.sample(200000, random_state=42)

# %%
def burnout_category(score):
    if score < 5:
        return 0   # Low
    elif score < 7:
        return 1   # Moderate
    else:
        return 2   # High

# %%
train_df['burnout_category'] = train_df['burnout_score'].apply(
    burnout_category
)

# %%
plt.figure(figsize=(12,8))

sns.heatmap(
    sample_df.select_dtypes(include=np.number).corr(),annot=True,fmt='.2f',
    cmap='coolwarm'
)

plt.show()

# %%
important_features = ['stress_level','sleep_hours','anxiety_score','depression_score']
plt.figure(figsize=(8,8))

for i, col in enumerate(important_features):
    plt.subplot(2,2,i+1)
    sns.scatterplot(
        x=sample_df[col],
        y=sample_df['burnout_score']
    )
    plt.title(f'{col} vs burnout')

plt.tight_layout()
plt.show()

# %% [raw]
# # Selected features based on correlation analysis from the heatmap and domain understanding of factors that commonly contribute to burnout.
# # Features with stronger relationships to burnout score such as stress,anxiety, depression, sleep, and academic pressure were included to improve the model’s predictive performance.

# %%
features = [
    'study_hours_per_day',
    'exam_pressure',
    'stress_level',
    'anxiety_score',
    'depression_score',
    'sleep_hours',
    'physical_activity',
    'social_support',
    'financial_stress',
    'family_expectation'
]

# %%
#dividing the data into X and y

X = train_df[features]
y = train_df['burnout_category']

# %%
#train test split 

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,stratify=y,random_state=42)

# %% [raw]
# # Logistic Regression was chosen as a simple baseline model because it works well for classification problems and provides interpretable results.
#
# # Random Forest Classifier was selected because it can handle non linear relationships, reduce overfitting, and work well with complex feature interactions.
#
# # Hist Gradient Boosting Classifier was used because it is an efficient boosting algorithm that often provides high accuracy on structured/tabular datasets and handles large datasets effectively.

# %%
from sklearn.linear_model import LogisticRegression

lr_model = LogisticRegression(max_iter=1000)

lr_model.fit(X_train, y_train)
lr_preds = lr_model.predict(X_test)

print("Logistic Regression")
print(classification_report(y_test, lr_preds))
# Out:
# Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     38153
#            1       0.60      0.37      0.46      1689
#            2       0.66      0.22      0.33       158
#
#     accuracy                           0.96     40000
#    macro avg       0.74      0.53      0.59     40000
# weighted avg       0.96      0.96      0.96     40000

# %% [raw]
# Logistic Regression achieved high overall accuracy due to dominance of low-burnout samples. However, the model struggled to correctly identify moderate and high burnout cases, indicating sensitivity to class imbalance.

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(n_estimators=50, max_depth=10, class_weight='balanced', random_state=42)

rf_model.fit(X_train, y_train)
rf_preds = rf_model.predict(X_test)

print("Random Forest")
print(classification_report(y_test, rf_preds))
# Out:
# Random Forest
#               precision    recall  f1-score   support
#
#            0       0.99      0.89      0.94     38153
#            1       0.25      0.81      0.38      1689
#            2       0.33      0.51      0.40       158
#
#     accuracy                           0.89     40000
#    macro avg       0.52      0.74      0.57     40000
# weighted avg       0.96      0.89      0.91     40000

# %% [raw]
# Random Forest significantly improved recall for moderate and high burnout categories. Although overall accuracy decreased slightly, the model demonstrated better capability in identifying high-risk students.

# %%
from sklearn.ensemble import HistGradientBoostingClassifier

hgb_model = HistGradientBoostingClassifier(random_state=42)

hgb_model.fit(X_train, y_train)
hgb_preds = hgb_model.predict(X_test)

print("HistGradientBoosting")
print(classification_report(y_test, hgb_preds))
# Out:
# HistGradientBoosting
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     38153
#            1       0.57      0.30      0.39      1689
#            2       0.33      0.24      0.28       158
#
#     accuracy                           0.96     40000
#    macro avg       0.62      0.51      0.55     40000
# weighted avg       0.95      0.96      0.95     40000

# %% [raw]
# HistGradientBoosting provided fast training and high overall accuracy but showed lower performance in detecting minority burnout classes compared to Random Forest.

# %% [markdown]
# Accuracy is misleading here.
# Because: Low burnout dominates dataset
# So: even weak models can get high accuracy
#
# recall for minority classes matters more

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, rf_preds)
sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues'
)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Random Forest Confusion Matrix")
plt.show()

# %% [raw]
# The Random Forest model demonstrated strong performance in detecting low and moderate burnout levels while maintaining reasonable detection capability for high burnout cases despite severe class imbalance. Importantly, the model rarely misclassified high-risk students as low risk, making it more reliable for practical burnout screening applications.

# %%
joblib.dump(rf_model, 'burnout_model.pkl')
# Out:
# ['burnout_model.pkl']

# %%
def predict_burnout(data):

    prediction = rf_model.predict([data])[0]

    if prediction == 0:
        return "Low Burnout"

    elif prediction == 1:
        return "Moderate Burnout"

    else:
        return "High Burnout"

# %%
student = [
    6,
    8,
    7,
    6,
    5,
    4,
    2,
    3,
    7,
    8
]

print(predict_burnout(student))
# Out:
# High Burnout

# %%
student = [
    2,
    2,
    2,
    1,
    1,
    8,
    8,
    8,
    1,
    2
]
print(predict_burnout(student))
# Out:
# Low Burnout

# %%
student = [
    5,
    5,
    5,
    4,
    4,
    6,
    5,
    5,
    5,
    5
]
print(predict_burnout(student))
# Out:
# Low Burnout
